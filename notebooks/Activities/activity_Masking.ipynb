# %%
import numpy as np
from IPython.display import Audio

# %% [markdown]
# ## Tone masking

# %% [markdown]
# 1) Create an envelope for a sinusoid so that you have a gradually increasing loudness (starting from zero)

# %%
#target
fs=44100
f0_1 = 315
env = np.linspace(0,.4,fs*2)
t = np.arange(0,2,1/fs)
tone1 = np.sin(2*np.pi*f0_1*t)*env
Audio(tone1, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 2) Pick another sinusoid within the same critical band as the one you made in step 1. (The second sound should have amplitude equal to the maximum value of the first sound (from #1)

# %%
#masker
f0_2 = 300
tone2 = 2*np.sin(2*np.pi*f0_2*t)
Audio(tone2, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 3) Combine the sounds

# %%
both = tone2+tone1

# %% [markdown]
# 4) Listen to the output. When do you hear one sound become two?

# %%
Audio(both,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# CB calculation (works, but...)

# %%
import math
f=290
bw = 25+ 75*(math.pow(1+(1.4*(f/1000)**2),0.69))
bw
# Out:
# 105.98720492647145

# %% [markdown]
# ## Noise masking

# %% [markdown]
# 1) Create a masking signal comprising of white noise (i.e., random array)

# %%
noi=np.random.randn(t.size)
Audio(noi,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 2) Pick a frequency for a sinusoid within a critical band. Apply the same envelope to the sinusoid as from above (it should gradually get louder starting from 0)

# %% [markdown]
# 3) Based on that critical band's bandwidth, filter the noise (masker) using a butterworth bandpass filter. (This creates narrow band noise centered around the critical band center frequency)

# %%
from scipy.signal import sawtooth, square, butter, filtfilt
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='bandpass')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = filtfilt(b, a, data)
    return y

# %%
noi2 = butter_bandpass_filter(noi,250,350,44100,5)
Audio(noi2,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# 4) Keeping the noise (masker) at a constant amplitude, combine with the sinusoid that gradually gets louder. When do you hear the target?

# %% [markdown]
# 5) Change the filter response of the noise to higher or lower. Repeat this experiment while keeping the original sinusoid frequency constant. Does it work the second time?

# %% [markdown]
# ## Temporal masking with pure tones

# %% [markdown]
# 1) Create a sinusoid at 500 Hz. Apply a .5 Hz sinusoid *as an envelope* to filter the amplitude of the sinusoid (so you don't have clips). It should be 10ms in duration.

# %% [markdown]
# 2) Make a series of masking tones at 275Hz, 500Hz, and 575 Hz. Each one should be 110ms long. Use your ADSR function to apply a 5ms attack slope and 5ms decay slope.

# %% [markdown]
# 2) Try zero padding a signal and then adding the target following the masker at the following time delays between masker offset and probe onset: 0, 10, 20, 60ms. Which Tones and delays get masked?

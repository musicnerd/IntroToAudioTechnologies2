# %% [markdown]
# ## Activity: Modeling
# Import the .csv file called "ionosphere.csv" and save to a pandas DataFrame. You can read about this package [here](https://archive.ics.uci.edu/ml/datasets/Ionosphere)

# %% [markdown]
# Note that you can set the printing options by adjusting with these parameters:
#
# pd.set_option('display.max_rows', 500)<br>
# pd.set_option('display.max_columns', 40)
#
# This will allow you to scroll but still avoid the "..." truncation.

# %% [markdown]
# 1) Get rid of the two binary columns 'V1' and 'V2' using `pd.DataFrame.drop`

# %%
import pandas as pd
data = pd.read_csv('ionosphere.csv')
iris = pd.read_csv('iris.csv')

# %%
iris.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
data.drop()

# %%
dep = data.iloc[:,-1]
feat = data.iloc[:,2:-1]

# %%
feat.head()
# Out:
#         V3       V4       V5       V6       V7       V8       V9      V10  \
# 0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000  0.03760
# 1  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000 -0.04549
# 2  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965  0.01198
# 3  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000  0.00000
# 4  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152 -0.16399
#
#        V11      V12  ...      V25      V26      V27      V28      V29  \
# 0  0.85243 -0.17755  ...  0.56811 -0.51171  0.41078 -0.46168  0.21266
# 1  0.50874 -0.67743  ... -0.20332 -0.26569 -0.20468 -0.18401 -0.19040
# 2  0.73082  0.05346  ...  0.57528 -0.40220  0.58984 -0.22145  0.43100
# 3  0.00000  0.00000  ...  1.00000  0.90695  0.51613  1.00000  1.00000
# 4  0.52798 -0.20275  ...  0.03286 -0.65158  0.13290 -0.53206  0.02431
#
#        V30      V31      V32      V33      V34
# 0 -0.34090  0.42267 -0.54487  0.18641 -0.45300
# ...

# %% [markdown]
# 2) Compute correlations between features in table format. Ignore the last ('Class') cell.

# %%
feat.corr() > .9
# Out:
#         V3     V4     V5     V6     V7     V8     V9    V10    V11    V12  \
# V3    True  False  False  False  False  False  False  False  False  False
# V4   False   True  False  False  False  False  False  False  False  False
# V5   False  False   True  False  False  False  False  False  False  False
# V6   False  False  False   True  False  False  False  False  False  False
# V7   False  False  False  False   True  False  False  False  False  False
# V8   False  False  False  False  False   True  False  False  False  False
# V9   False  False  False  False  False  False   True  False  False  False
# V10  False  False  False  False  False  False  False   True  False  False
# V11  False  False  False  False  False  False  False  False   True  False
# V12  False  False  False  False  False  False  False  False  False   True
# V13  False  False  False  False  False  False  False  False  False  False
# V14  False  False  False  False  False  False  False  False  False  False
# ...

# %% [markdown]
# 3) Plot a color plot to display items that might be strongly correlated (we might say 'strong' is above .8). Make your figure a decent size.

# %% [markdown]
# 4) Since there are a lot of data points, use filtering to identify where in the table there is any correlation greater or equal to .8

# %% [markdown]
# 5) Make two subsets of your dataset based on the 'Class' category

# %% [markdown]
# 6) Make a single plot with two subplots stacked vertically and with a very large figure width, one plot for 'good' and one for 'bad' showing all features simultaneously. (You don't need a legend)

# %% [markdown]
# 7) Convert your 'Class' column of data to a single binary variable with zeros and ones. You can either do this manually or else use the `pd.get_dummies` function showed in the Lesson. Swap out or convert the existing 'Class' column for the dummy.

# %% [markdown]
# 8) Divide your data into two subsets: the data column with the ground truth (or "target" variable) and the data columns with the feature data. Call the subsets 'target' and 'features' respectively.

# %% [markdown]
# 9) Split your data into training and test sets using the `sklearn` packages as per the lesson instructions. Add a 'random state' variable by setting equal to any integer value (same as 'seed' in other programs we have used this year. Ensures that your data should output the same values every time you run -- note that this does not mean it will output the same as everyone else!)

# %% [markdown]
# 10) Run (i.e., "fit") the model with `LogisticRegression` using `solver='lbfgs'` and save the output to a variable called "model"

# %% [markdown]
# 11) Print your model coefficients with the method `model.coef_` There will be one for every column (or feature)

# %% [markdown]
# 12) Compute a confusion matrix showing your model results

# %% [markdown]
# 13) Print your classification reports using
#
# `from sklearn.metrics import classification_report`

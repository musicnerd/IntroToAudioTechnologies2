# %%
#Testing all packages:
# from numpy import *
# from scipy import *
# from librosa import *
# from matplotlib import *
from seaborn import *
from pandas import *
from music21 import *
from pretty_midi import *
from IPython.display import *

# %%
import numpy as np
from scipy.io.wavfile import read

# %%
fs, x = read('../uploaded_audio/flute-A4.wav')

# %%
import matplotlib.pyplot as plt
plt.plot(x)

# %%
t = np.arange(0,x.size/fs,1/fs)
##OR##
# t = np.linspace(0,x.size/fs)
plt.plot(t,x)

# %%
#convert to MS
plt.plot(t*1000,x)

# %%
#normalize values to beween -1 and 1:
x.max()
# Out:
# 6572

# %%
newx = x/np.abs(x).max()
plt.plot(np.flip(newx))
